# %%
import pandas as pd

df_employees = pd.read_csv("employees.csv")
df_jobs = pd.read_csv("jobs.csv")

# %%
print("Puestos de trabajo en employees.csv:", df_employees["JobRole"].nunique(), "\n")
print(df_employees["JobRole"].unique())
# Out:
# Puestos de trabajo en employees.csv: 9
#
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']

# %%
print("Puestos de trabajo en jobs.csv:", df_jobs["job_title"].nunique(), "\n")
print(df_jobs["job_title"].unique())
# Out:
# Puestos de trabajo en jobs.csv: 10
#
# ['Policy Analyst' 'Data Scientist' 'Product Manager' 'ML Engineer'
#  'Software Engineer' 'Systems Engineer' 'AI Researcher'
#  'Operations Manager' 'Research Scientist' 'Business Analyst']

# %%
skills = df_jobs["core_skills"].str.split(', ').explode().unique()
print("Habilidades en jobs.csv:", len(skills), "\n")
print(skills)
# Out:
# Habilidades en jobs.csv: 10
#
# ['Research' 'Project Management' 'Business Analysis' 'SQL' 'Python'
#  'Cloud Computing' 'Data Analysis' 'Statistics' 'Communication'
#  'Software Engineering']
